# %%
#Varvara Yakovleva

# %%
#import libraries
from sklearn.cross_validation import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
#import dataset
dataset = pd.read_csv('regLin.csv')
X = dataset[dataset.columns[0:-1]] 
Y = dataset[dataset.columns[-1]]

# %%
#divide data 
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, train_size=0.75)

# %%
regr = LinearRegression()
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#create plot
plt.scatter(X_train,Y_train)
plt.title("Training set")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(X_train, regr.predict(X_train), color = 'black')
plt.show()

# %%
#create plot
plt.scatter(X_test,Y_test)
plt.title("Test set")
plt.xlabel("X")
plt.ylabel("Y")
plt.plot(X_train, regr.predict(X_train), color = 'black')
plt.show()

# %%
w0 = regr.intercept_
w1 = regr.coef_[0]
w = np.linspace(-regr.intercept_, regr.intercept_, num=100)

# %%
def Error(w0, w1, X,Y):
    indices = X.index.values
    error = 0
    for i in range (0, len(indices)):
        index = indices[i]
        x = X['X'][index]
        y = Y[index]
        error += (y - (w1 * x + w0)) ** 2
    return error / float(len(X))

for i in range(0, len(w)):
    x = Error(w[i], w1, X_train, Y_train)
    df = df.append({'int': w[i], 'error': x}, ignore_index=True)

plt.scatter(df['int'], df['error'])
plt.xlabel("Error")
plt.scatter(w0,np.mean(((w1*dataset['X']+w0)-dataset['y'])**2),color = 'red')
plt.show()
